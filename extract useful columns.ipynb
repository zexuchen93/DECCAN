# %%
import pandas as pd
import numpy as np
from pandas import ExcelWriter
from pandas import ExcelFile

df = pd.read_excel('July 2018 to Nov 2019 -no notes.xlsx')

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df.head()
# Out:
#    Address_Formatted            AddressCityStateZip           addtst  age agency  alarmcnt  alarmlev  alarmtype  alerts_cnt  alrm_id  apt                 atime  AvStatus  bolid      bphone  bprem_cnt busi_type business  cadnameid  calldow                  calleraddr         callernm      callerph callgroup  calllineno  callrefno callsource  calltaker             calltime  cancelled    case_id case_id2 casenumreq city citydesc CityStateZip  ClearTime closecode closecomm  Col1  Col2 console      crossroad1         crossroad2  cs_idpict  cs_idpict2                 ctime  DBConnection  dig_code  digdisp  disp_req  DispatchTime district                 dtime  Duplicated emsgroup                 etime firegroup            firstarrv firstdisp             firstdtm             firstenr            firsttran FormattedCaseID FormattedIDKey  geoemds  geoemgp  geoemra  geoemresp  geoems  geoemst geofire geofrds geofrgp  geofrra  geofrresp geofrst geolaw  geolwbt geolwds geolwgp  geolwpr  geolwra  
# ...

# %%
df.columns
# Out:
# Index(['Address_Formatted', 'AddressCityStateZip', 'addtst', 'age', 'agency',
#        'alarmcnt', 'alarmlev', 'alarmtype', 'alerts_cnt', 'alrm_id',
#        ...
#        'utimeclose', 'utimefini', 'utimeready', 'utimeroute', 'vehicleid',
#        'vehstate', 'verloc', 'vernat', 'wanted_cnt', 'zip'],
#       dtype='object', length=254)

# %%
col_names = ['TimeRoute', 'Firstdtm','DTIME','ETIME' ,'ATIME','TTIME','HTIME','CTIME','BTIME','CallTime','LTRecpt','TimeReady','TimeRoute','CallSource','NatureCode','Nature','Street','CityDesc','GeoX','GeoY']

# %%
col_names = [x.lower() for x in col_names]

# %%
df3 = df.loc[:, col_names ]
# Out:
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
df3.head()
# Out:
#              timeroute             firstdtm                 dtime                 etime                 atime                 ttime                 htime                 ctime  btime             calltime  ltrecpt            timeready            timeroute callsource naturecode                nature             street citydesc      geox        geoy
# 0  04/01/2019 00:05:59  04/01/2019 00:06:42  4/1/2019 12:06:42 AM  4/1/2019 12:08:35 AM                   NaN  4/1/2019 12:33:08 AM  4/1/2019 12:46:50 AM   4/1/2019 1:10:59 AM    NaN  04/01/2019 00:05:59      NaN  04/01/2019 00:05:12  04/01/2019 00:05:59      PHONE       NAUN         NATURE UNKNOW     240-B N 4TH ST  HAMPTON  12127113  3548039.25
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81662 entries, 0 to 81661
# Data columns (total 20 columns):
# timeroute     81309 non-null object
# firstdtm      77196 non-null object
# dtime         77160 non-null object
# etime         71825 non-null object
# atime         58562 non-null object
# ttime         20508 non-null object
# htime         20371 non-null object
# ctime         74386 non-null object
# btime         0 non-null float64
# calltime      81662 non-null object
# ltrecpt       0 non-null float64
# timeready     79331 non-null object
# timeroute     81309 non-null object
# callsource    81662 non-null object
# naturecode    81662 non-null object
# nature        81661 non-null object
# street        81642 non-null object
# citydesc      81366 non-null object
# geox          81662 non-null int64
# geoy          81662 non-null float64
# dtypes: float64(3), int64(1), object(16)
# memory usage: 12.5+ MB

# %%
df3.describe()
# Out:
#        btime  ltrecpt          geox          geoy
# count    0.0      0.0  8.166200e+04  8.166200e+04
# mean     NaN      NaN  1.207219e+07  3.534783e+06
# std      NaN      NaN  6.116445e+05  1.792572e+05
# min      NaN      NaN  0.000000e+00  0.000000e+00
# 25%      NaN      NaN  1.209411e+07  3.538484e+06
# 50%      NaN      NaN  1.210116e+07  3.544367e+06
# 75%      NaN      NaN  1.211235e+07  3.549178e+06
# max      NaN      NaN  1.213549e+07  3.632226e+06

# %%
df3.to_excel("selected columns 201807-201911.xlsx")

# %%
df2 = df.loc[:, ['dtime']]

# %%
col_new = ['Cancelled','Initialize','medicalpri','name','neighbor','liveevent','formattedi',' formattedc','col1','col2','ordercol','avstatus','timestamp']

# %%
col_new = [x.lower() for x in col_new]
df4 = df.loc[:, col_new ]

# %%
df4.head()
# Out:
#    cancelled  initialize  medicalpri  name  neighbor  liveevent  formattedi   formattedc  col1  col2  ordercol  avstatus  timestamp
# 0          0         NaN         NaN   NaN       NaN        NaN         NaN          NaN   NaN   NaN       NaN       NaN        NaN
# 1          0         NaN         NaN   NaN       NaN        NaN         NaN          NaN   NaN   NaN       NaN       NaN        NaN
# 2          0         NaN         NaN   NaN       NaN        NaN         NaN          NaN   NaN   NaN       NaN       NaN        NaN
# 3          0         NaN         NaN   NaN       NaN        NaN         NaN          NaN   NaN   NaN       NaN       NaN        NaN
# 4          0         NaN         NaN   NaN       NaN        NaN         NaN          NaN   NaN   NaN       NaN       NaN        NaN

# %%
str_df = pd.read_excel("previous structure.xlsx")

# %%
str_df
# Out:
#    cancelled  InitializeRTFNotes MedicalPriorityLevel_Abbreviated  Name  Neighbor  LiveEvent FormattedIDKey FormattedCaseID  Col1  Col2  OrderCol  AvStatus  TimeStamp  TransactionType  UnitPerID Primeoffc                       addtst  age agency  alarmcnt  alrm_id  alarmlev  alarmtype  alerts_cnt  apt  bolid     business        bphone  bprem_cnt busi_type  cadnameid  calldow           calleraddr    callernm      callerph callgroup  calllineno  callrefno callsource   calltaker             calltime  secscallt    case_id case_id2  cs_idpict2  cs_idpict casenumreq city     citydesc closecode  closecomm console       crossroad1       crossroad2  digdisp  dig_code  disp_req  district emsgroup   inci_pict firegroup            firstarrv firstdisp             firstdtm             firstenr            firsttran  geoems  geoemds  geoemgp  geoemra  geoemresp  geoemst geofire  geofrds geofrgp  geofrra  geofrresp geofrst geolaw  geolwbt geolwds geolwgp  geolwpr  geolwra geolwresp  geonatspor  \
# ...

# %%
col_wanted = []
for ele in str_df:
    col_wanted.append(ele)
print(col_wanted)
# Out:
# ['cancelled', 'InitializeRTFNotes', 'MedicalPriorityLevel_Abbreviated', 'Name', 'Neighbor', 'LiveEvent', 'FormattedIDKey', 'FormattedCaseID', 'Col1', 'Col2', 'OrderCol', 'AvStatus', 'TimeStamp', 'TransactionType', 'UnitPerID', 'Primeoffc', 'addtst', 'age', 'agency', 'alarmcnt', 'alrm_id', 'alarmlev', 'alarmtype', 'alerts_cnt', 'apt', 'bolid', 'business', 'bphone', 'bprem_cnt', 'busi_type', 'cadnameid', 'calldow', 'calleraddr', 'callernm', 'callerph', 'callgroup', 'calllineno', 'callrefno', 'callsource', 'calltaker', 'calltime', 'secscallt', 'case_id', 'case_id2', 'cs_idpict2', 'cs_idpict', 'casenumreq', 'city', 'citydesc', 'closecode', 'closecomm', 'console', 'crossroad1', 'crossroad2', 'digdisp', 'dig_code', 'disp_req', 'district', 'emsgroup', 'inci_pict', 'firegroup', 'firstarrv', 'firstdisp', 'firstdtm', 'firstenr', 'firsttran', 'geoems', 'geoemds', 'geoemgp', 'geoemra', 'geoemresp', 'geoemst', 'geofire', 'geofrds', 'geofrgp', 'geofrra', 'geofrresp', 'geofrst', 'geolaw', 'geolwbt'
# ...

# %%
df5  = df.loc[:, col_wanted ]

# %%
df5
# Out:
#        cancelled  InitializeRTFNotes MedicalPriorityLevel_Abbreviated  Name  Neighbor  LiveEvent FormattedIDKey FormattedCaseID  Col1  Col2  OrderCol  AvStatus  TimeStamp  TransactionType  UnitPerID Primeoffc           addtst  age agency  alarmcnt  alrm_id  alarmlev  alarmtype  alerts_cnt  apt  bolid business      bphone  bprem_cnt busi_type  cadnameid  calldow                  calleraddr         callernm      callerph callgroup  calllineno  callrefno callsource  calltaker             calltime  secscallt    case_id case_id2  cs_idpict2  cs_idpict casenumreq city      citydesc closecode closecomm     console      crossroad1         crossroad2  digdisp  dig_code  disp_req district emsgroup   inci_pict firegroup            firstarrv firstdisp             firstdtm             firstenr            firsttran  geoems  geoemds  geoemgp  geoemra  geoemresp  geoemst geofire geofrds geofrgp  geofrra  geofrresp geofrst geolaw  geolwbt geolwds geolwgp  geolwpr  geolwra geolwresp  geonatspor  \
# ...

# %%
df5.describe()
# Out:
#           cancelled  InitializeRTFNotes  Name  Neighbor  LiveEvent  Col1     Col2  OrderCol  AvStatus  TimeStamp  TransactionType  UnitPerID  age      alarmcnt  alrm_id      alarmlev  alarmtype    alerts_cnt  apt    bolid  bprem_cnt  cadnameid       calldow      callerph  calllineno     callrefno     secscallt  cs_idpict2  digdisp  dig_code  disp_req  geoems  geoemds  geoemgp  geoemra  geoemresp  geoemst  geofrra  geofrresp       geolwbt  geolwpr       geolwra  geonatspor      geoneigh  geoothr1  geoothr2  geoothrds  geoothrgp  geoothrra  geoothrrsp  geoothrst  georesc  georescds  georescgp  georescra  georescrsp  georescst  georesp  geortr  geosubd  geotow          geox          geoy  hazmat_cnt      hist_cnt     hotsp_cnt     hours_hot  id2agency  image_cnt  mapbmp     maxarv_tm    maxcall_tm     maxdis_tm     maxenr_tm     maxhos_tm     maxtos_tm      medprior  nature2     naturechg      natureid  notes  notes2     parent_id  precinct      prem_cnt  prememresp  premfrresp  \
# ...

# %%
df5.to_excel('previous structure as ref.xlsx')
