# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import os
import pandas as pd

# %%
path = os.getcwd()
files = os.listdir(path)
files
# Out:
# ['.ipynb_checkpoints',
#  'April2019.xlsx',
#  'August2018.xlsx',
#  'December2018.xlsx',
#  'February2019.xlsx',
#  'January2019.xlsx',
#  'July 2018.xlsx',
#  'June2019.xlsx',
#  'March2019.xlsx',
#  'May2019.xlsx',
#  'November2018.xlsx',
#  'October2018.xlsx',
#  'September2018.xlsx',
#  'Thumbs.db',
#  'Untitled.ipynb']

# %%
files_xls = [f for f in files if f[-4:] == 'xlsx']
files_xls
# Out:
# ['April2019.xlsx',
#  'August2018.xlsx',
#  'December2018.xlsx',
#  'February2019.xlsx',
#  'January2019.xlsx',
#  'July 2018.xlsx',
#  'June2019.xlsx',
#  'March2019.xlsx',
#  'May2019.xlsx',
#  'November2018.xlsx',
#  'October2018.xlsx',
#  'September2018.xlsx']

# %%
df = pd.DataFrame()

# %%
for f in files_xls:
    data = pd.read_excel(f)
    df = df.append(data)

# %%
df
# Out:
#          Address_Formatted               AddressCityStateZip           addtst  \
# 0           240-B N 4TH ST        240-B N 4TH ST, HA,  23664              NaN
# 1        25 WYTHE CREEK RD     25 WYTHE CREEK RD, HA,  23665   DIST: 74.65 ft
# 2             135 SESCO DR          135 SESCO DR, HA,  23664  DIST: 408.88 ft
# 3          3000 KENMORE DR       3000 KENMORE DR, HA,  23661              NaN
# 4           110-H MISTY CV        110-H MISTY CV, HA,  23666              NaN
# ...                    ...                               ...              ...
# 5052  2905 N ARMISTEAD AVE  2905 N ARMISTEAD AVE, HA,  23666              NaN
# 5053  2905 N ARMISTEAD AVE  2905 N ARMISTEAD AVE, HA,  23666              NaN
# 5054  2905 N ARMISTEAD AVE  2905 N ARMISTEAD AVE, HA,  23666              NaN
# 5055  2905 N ARMISTEAD AVE  2905 N ARMISTEAD AVE, HA,  23666              NaN
# 5056  2905 N ARMISTEAD AVE  2905 N ARMISTEAD AVE, HA,  23666              NaN
#
# ...

# %%
df.to_csv("201807-201906.csv")
